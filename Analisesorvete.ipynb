# %% [markdown]
# <a href="https://colab.research.google.com/github/feliperibeiro01-GPI/FONTE_DADOS/blob/main/Analisesorvete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Análise de dados sobre sorvete

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sakshisatre/ice-cream-sales-dataset")

print("Caminho para os arquivos conjuntos de dados:", path)
# Out:
# ...
# 100%|██████████| 2.09k/2.09k [00:00<00:00, 2.08MB/s]
# Extracting files...
# Caminho para os arquivos conjuntos de dados: /root/.cache/kagglehub/datasets/sakshisatre/ice-cream-sales-dataset/versions/1

# %%
import pandas as pd
import os

# The dataset was downloaded to this path
dataset_path = "/root/.cache/kagglehub/datasets/sakshisatre/ice-cream-sales-dataset/versions/1"

# Construct the full path to the CSV file
csv_file_path = os.path.join(dataset_path, "Ice Cream.csv")

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
display(df.head(5))
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create a scatter plot of Temperature vs Revenue
plt.figure(figsize=(10, 6))
plt.scatter(df['Temperature'], df['Revenue'], label='Data Points')

# Generate points for the regression line
temp_range = np.linspace(df['Temperature'].min(), df['Temperature'].max(), 100).reshape(-1, 1)
predicted_revenue = model.predict(temp_range)

# Plot the regression line
plt.plot(temp_range, predicted_revenue, color='red', label='Linear Regression Line')

plt.xlabel('Temperature (°C)')
plt.ylabel('Revenue ($)')
plt.title('Revenue vs Temperature with Linear Regression')
plt.grid(True)
plt.legend()
plt.show()
